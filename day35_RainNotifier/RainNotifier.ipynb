# %% [markdown]
# # Day 35 - API Keys, Authentication and Environment Variables

# %% [markdown]
# ### What is API Authentication?
#
# API authentication is the process of ``verifying the identity of a client application`` that is ``trying to access an API``. This is typically done by providing an API key or token that is unique to the client application. The ``API key or token is usually included in the request headers or query parameters``, and is used by the API server to ``authenticate`` and ``authorize`` the client application to access the requested resources. API authentication is important for security reasons, as it helps to ``prevent unauthorized access`` to sensitive data or functionality.

# %% [markdown]
# ### API Key
#
# An API key is a unique identifier that is used to ``authenticate`` a client application or user. API keys are typically ``32-character`` strings that are ``hexadecimal`` in nature. They are generated by the API provider.

# %% [markdown]
# ### Excercise: Using API Key to Authenticate and get Weather from OpenWeatherMap API

# %%
# Documentation: https://openweathermap.org/api/one-call-api
import requests

# 49.008091, 8.403760 - Karlsruhe, Germany

params = {
    'lat': 49.008091, 
    'lon' : 8.403760,
    'appid': "[YOUR API KEY]",
    'exclude': 'minutely,daily,current'
}

response = requests.get("https://api.openweathermap.org/data/3.0/onecall?", params=params)
response.raise_for_status()

print(response.json())
# Out:
# {'lat': 49.0081, 'lon': 8.4038, 'timezone': 'Europe/Berlin', 'timezone_offset': 3600, 'hourly': [{'dt': 1699372800, 'temp': 282.51, 'feels_like': 279.89, 'pressure': 1014, 'humidity': 82, 'dew_point': 279.6, 'uvi': 0, 'clouds': 83, 'visibility': 10000, 'wind_speed': 5.14, 'wind_deg': 219, 'wind_gust': 11, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'pop': 0}, {'dt': 1699376400, 'temp': 282.17, 'feels_like': 279.49, 'pressure': 1015, 'humidity': 83, 'dew_point': 279.44, 'uvi': 0, 'clouds': 82, 'visibility': 10000, 'wind_speed': 5.05, 'wind_deg': 219, 'wind_gust': 11.94, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'pop': 0.2, 'rain': {'1h': 0.1}}, {'dt': 1699380000, 'temp': 281.73, 'feels_like': 278.98, 'pressure': 1015, 'humidity': 84, 'dew_point': 279.18, 'uvi': 0, 'clouds': 77, 'visibility': 10000, 'wind_speed': 4.97, 'wind_deg': 221, 'wind_gust': 12.17, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'pop': 0}, {'dt': 1699383600, 'temp': 281.32, 'feels_like': 278.35, 'pressure': 1016, 'humidity': 84, 'dew_point': 278.78, 'uvi': 0, 'clouds': 40, 'visibility': 10000, 'wind_speed': 5.26, 'wind_deg': 220, 'wind_gust': 12.42, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'pop': 0}, {'dt': 1699387200, 'temp': 280.93, 'feels_like': 277.82, 'pressure': 1017, 'humidity': 82, 'dew_point': 278.05, 'uvi': 0, 'clouds': 24, 'visibility': 10000, 'wind_speed': 5.34, 'wind_deg': 220, 'wind_gust': 12.49, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'pop': 0}, {'dt': 1699390800, 'temp': 280.62, 'feels_like': 277.39, 'pressure': 1018, 'humidity': 81, 'dew_point': 277.39, 'uvi': 0, 'clouds': 8, 'visibility': 10000, 'wind_speed': 5.45, 'wind_deg': 222, 'wind_gust': 12.16, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699394400, 'temp': 280.38, 'feels_like': 277.21, 'pressure': 1019, 'humidity': 82, 'dew_point': 277.3, 'uvi': 0, 'clouds': 8, 'visibility': 10000, 'wind_speed': 5.16, 'wind_deg': 222, 'wind_gust': 12.26, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699398000, 'temp': 280.2, 'feels_like': 277.05, 'pressure': 1019, 'humidity': 83, 'dew_point': 277.35, 'uvi': 0, 'clouds': 7, 'visibility': 10000, 'wind_speed': 5.01, 'wind_deg': 222, 'wind_gust': 12.23, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699401600, 'temp': 280.01, 'feels_like': 276.83, 'pressure': 1019, 'humidity': 84, 'dew_point': 277.29, 'uvi': 0, 'clouds': 7, 'visibility': 10000, 'wind_speed': 4.97, 'wind_deg': 222, 'wind_gust': 12.27, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699405200, 'temp': 279.75, 'feels_like': 276.64, 'pressure': 1019, 'humidity': 84, 'dew_point': 277.07, 'uvi': 0, 'clouds': 7, 'visibility': 10000, 'wind_speed': 4.66, 'wind_deg': 223, 'wind_gust': 12.07, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699408800, 'temp': 279.53, 'feels_like': 276.45, 'pressure': 1019, 'humidity': 84, 'dew_point': 276.89, 'uvi': 0, 'clouds': 6, 'visibility': 10000, 'wind_speed': 4.49, 'wind_deg': 226, 'wind_gust': 12.14, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699412400, 'temp': 279.37, 'feels_like': 276.18, 'pressure': 1019, 'humidity': 84, 'dew_point': 276.74, 'uvi': 0, 'clouds': 8, 'visibility': 10000, 'wind_speed': 4.64, 'wind_deg': 229, 'wind_gust': 12.1, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'pop': 0}, {'dt': 1699416000, 'temp': 279.18, 'feels_like': 276.08, 'pressure': 1020, 'humidity': 85, 'dew_point': 276.63, 'uvi': 0, 'clouds': 9, 'visibi ...

# %%
import json

json_obj = json.loads(response.text)
print(json.dumps(json_obj, indent=4, sort_keys=True))
# Out:
# {
#     "hourly": [
#         {
#             "clouds": 83,
#             "dew_point": 279.6,
#             "dt": 1699372800,
#             "feels_like": 279.89,
#             "humidity": 82,
#             "pop": 0,
#             "pressure": 1014,
#             "temp": 282.51,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 219,
#             "wind_gust": 11,
#             "wind_speed": 5.14
#         },
#         {
#             "clouds": 82,
#             "dew_point": 279.44,
#             "dt": 1699376400,
#             "feels_like": 279.49,
#             "humidity": 83,
#             "pop": 0.2,
#             "pressure": 1015,
#             "rain": {
#                 "1h": 0.1
#             },
#             "temp": 282.17,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 219,
#             "wind_gust": 11.94,
#             "wind_speed": 5.05
#         },
#         {
#             "clouds": 77,
#             "dew_point": 279.18,
#             "dt": 1699380000,
#             "feels_like": 278.98,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1015,
#             "temp": 281.73,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 221,
#             "wind_gust": 12.17,
#             "wind_speed": 4.97
#         },
#         {
#             "clouds": 40,
#             "dew_point": 278.78,
#             "dt": 1699383600,
#             "feels_like": 278.35,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1016,
#             "temp": 281.32,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 220,
#             "wind_gust": 12.42,
#             "wind_speed": 5.26
#         },
#         {
#             "clouds": 24,
#             "dew_point": 278.05,
#             "dt": 1699387200,
#             "feels_like": 277.82,
#             "humidity": 82,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 280.93,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 220,
#             "wind_gust": 12.49,
#             "wind_speed": 5.34
#         },
#         {
#             "clouds": 8,
#             "dew_point": 277.39,
#             "dt": 1699390800,
#             "feels_like": 277.39,
#             "humidity": 81,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 280.62,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 222,
#             "wind_gust": 12.16,
#             "wind_speed": 5.45
#         },
#         {
#             "clouds": 8,
#             "dew_point": 277.3,
#             "dt": 1699394400,
#             "feels_like": 277.21,
#             "humidity": 82,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 280.38,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 222,
#             "wind_gust": 12.26,
#             "wind_speed": 5.16
#         },
#         {
#             "clouds": 7,
#             "dew_point": 277.35,
#             "dt": 1699398000,
#             "feels_like": 277.05,
#             "humidity": 83,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 280.2,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 222,
#             "wind_gust": 12.23,
#             "wind_speed": 5.01
#         },
#         {
#             "clouds": 7,
#             "dew_point": 277.29,
#             "dt": 1699401600,
#             "feels_like": 276.83,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 280.01,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 222,
#             "wind_gust": 12.27,
#             "wind_speed": 4.97
#         },
#         {
#             "clouds": 7,
#             "dew_point": 277.07,
#             "dt": 1699405200,
#             "feels_like": 276.64,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 279.75,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 223,
#             "wind_gust": 12.07,
#             "wind_speed": 4.66
#         },
#         {
#             "clouds": 6,
#             "dew_point": 276.89,
#             "dt": 1699408800,
#             "feels_like": 276.45,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 279.53,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 226,
#             "wind_gust": 12.14,
#             "wind_speed": 4.49
#         },
#         {
#             "clouds": 8,
#             "dew_point": 276.74,
#             "dt": 1699412400,
#             "feels_like": 276.18,
#             "humidity": 84,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 279.37,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 12.1,
#             "wind_speed": 4.64
#         },
#         {
#             "clouds": 9,
#             "dew_point": 276.63,
#             "dt": 1699416000,
#             "feels_like": 276.08,
#             "humidity": 85,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 279.18,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 11.81,
#             "wind_speed": 4.37
#         },
#         {
#             "clouds": 9,
#             "dew_point": 276.52,
#             "dt": 1699419600,
#             "feels_like": 276.12,
#             "humidity": 85,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 279.05,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 11.5,
#             "wind_speed": 3.99
#         },
#         {
#             "clouds": 15,
#             "dew_point": 276.45,
#             "dt": 1699423200,
#             "feels_like": 275.97,
#             "humidity": 87,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 278.67,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 233,
#             "wind_gust": 10.56,
#             "wind_speed": 3.46
#         },
#         {
#             "clouds": 97,
#             "dew_point": 276.69,
#             "dt": 1699426800,
#             "feels_like": 276.38,
#             "humidity": 86,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 279.06,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 10.73,
#             "wind_speed": 3.57
#         },
#         {
#             "clouds": 98,
#             "dew_point": 277.16,
#             "dt": 1699430400,
#             "feels_like": 277.9,
#             "humidity": 80,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 280.6,
#             "uvi": 0.06,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 10.23,
#             "wind_speed": 4.24
#         },
#         {
#             "clouds": 96,
#             "dew_point": 277.55,
#             "dt": 1699434000,
#             "feels_like": 279.04,
#             "humidity": 77,
#             "pop": 0,
#             "pressure": 1021,
#             "temp": 281.53,
#             "uvi": 0.16,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 231,
#             "wind_gust": 10.09,
#             "wind_speed": 4.26
#         },
#         {
#             "clouds": 96,
#             "dew_point": 277.64,
#             "dt": 1699437600,
#             "feels_like": 280.44,
#             "humidity": 71,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 282.82,
#             "uvi": 0.47,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 229,
#             "wind_gust": 9.42,
#             "wind_speed": 4.72
#         },
#         {
#             "clouds": 93,
#             "dew_point": 277.64,
#             "dt": 1699441200,
#             "feels_like": 282.75,
#             "humidity": 66,
#             "pop": 0,
#             "pressure": 1020,
#             "temp": 283.9,
#             "uvi": 0.61,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 231,
#             "wind_gust": 9.44,
#             "wind_speed": 5.06
#         },
#         {
#             "clouds": 85,
#             "dew_point": 277.78,
#             "dt": 1699444800,
#             "feels_like": 283.3,
#             "humidity": 64,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 284.44,
#             "uvi": 0.6,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 230,
#             "wind_gust": 8.89,
#             "wind_speed": 5.07
#         },
#         {
#             "clouds": 59,
#             "dew_point": 277.76,
#             "dt": 1699448400,
#             "feels_like": 283.63,
#             "humidity": 63,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 284.77,
#             "uvi": 0.77,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 225,
#             "wind_gust": 8.51,
#             "wind_speed": 4.72
#         },
#         {
#             "clouds": 36,
#             "dew_point": 277.83,
#             "dt": 1699452000,
#             "feels_like": 283.57,
#             "humidity": 63,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 284.71,
#             "uvi": 0.44,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 217,
#             "wind_gust": 8.01,
#             "wind_speed": 4.15
#         },
#         {
#             "clouds": 28,
#             "dew_point": 277.63,
#             "dt": 1699455600,
#             "feels_like": 282.59,
#             "humidity": 67,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 283.73,
#             "uvi": 0.17,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 206,
#             "wind_gust": 8.28,
#             "wind_speed": 3.78
#         },
#         {
#             "clouds": 25,
#             "dew_point": 277.37,
#             "dt": 1699459200,
#             "feels_like": 280.07,
#             "humidity": 75,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 281.76,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 185,
#             "wind_gust": 7.47,
#             "wind_speed": 2.88
#         },
#         {
#             "clouds": 37,
#             "dew_point": 277.07,
#             "dt": 1699462800,
#             "feels_like": 279.2,
#             "humidity": 79,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 280.72,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 169,
#             "wind_gust": 6.23,
#             "wind_speed": 2.37
#         },
#         {
#             "clouds": 47,
#             "dew_point": 276.78,
#             "dt": 1699466400,
#             "feels_like": 278.94,
#             "humidity": 80,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 280.11,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 174,
#             "wind_gust": 3.34,
#             "wind_speed": 1.86
#         },
#         {
#             "clouds": 53,
#             "dew_point": 276.43,
#             "dt": 1699470000,
#             "feels_like": 278.64,
#             "humidity": 81,
#             "pop": 0,
#             "pressure": 1016,
#             "temp": 279.67,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 171,
#             "wind_gust": 1.34,
#             "wind_speed": 1.66
#         },
#         {
#             "clouds": 76,
#             "dew_point": 276.24,
#             "dt": 1699473600,
#             "feels_like": 278.62,
#             "humidity": 81,
#             "pop": 0,
#             "pressure": 1016,
#             "temp": 279.51,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 179,
#             "wind_gust": 1.29,
#             "wind_speed": 1.52
#         },
#         {
#             "clouds": 84,
#             "dew_point": 276.11,
#             "dt": 1699477200,
#             "feels_like": 278.24,
#             "humidity": 81,
#             "pop": 0,
#             "pressure": 1015,
#             "temp": 279.28,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 180,
#             "wind_gust": 1.66,
#             "wind_speed": 1.62
#         },
#         {
#             "clouds": 76,
#             "dew_point": 275.91,
#             "dt": 1699480800,
#             "feels_like": 278,
#             "humidity": 82,
#             "pop": 0,
#             "pressure": 1014,
#             "temp": 279.01,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 178,
#             "wind_gust": 1.59,
#             "wind_speed": 1.56
#         },
#         {
#             "clouds": 69,
#             "dew_point": 275.77,
#             "dt": 1699484400,
#             "feels_like": 277.98,
#             "humidity": 82,
#             "pop": 0,
#             "pressure": 1014,
#             "temp": 278.82,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 180,
#             "wind_gust": 1.36,
#             "wind_speed": 1.41
#         },
#         {
#             "clouds": 74,
#             "dew_point": 275.81,
#             "dt": 1699488000,
#             "feels_like": 279.23,
#             "humidity": 79,
#             "pop": 0,
#             "pressure": 1013,
#             "temp": 279.23,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 180,
#             "wind_gust": 1.34,
#             "wind_speed": 1.25
#         },
#         {
#             "clouds": 100,
#             "dew_point": 275.6,
#             "dt": 1699491600,
#             "feels_like": 279.18,
#             "humidity": 79,
#             "pop": 0,
#             "pressure": 1013,
#             "temp": 279.18,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 183,
#             "wind_gust": 1.18,
#             "wind_speed": 1.1
#         },
#         {
#             "clouds": 100,
#             "dew_point": 275.29,
#             "dt": 1699495200,
#             "feels_like": 279.08,
#             "humidity": 78,
#             "pop": 0,
#             "pressure": 1012,
#             "temp": 279.08,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 173,
#             "wind_gust": 1.01,
#             "wind_speed": 1.06
#         },
#         {
#             "clouds": 100,
#             "dew_point": 274.79,
#             "dt": 1699498800,
#             "feels_like": 278.99,
#             "humidity": 75,
#             "pop": 0,
#             "pressure": 1011,
#             "temp": 278.99,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 174,
#             "wind_gust": 0.96,
#             "wind_speed": 1.08
#         },
#         {
#             "clouds": 100,
#             "dew_point": 274.25,
#             "dt": 1699502400,
#             "feels_like": 278.86,
#             "humidity": 73,
#             "pop": 0,
#             "pressure": 1010,
#             "temp": 278.86,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 202,
#             "wind_gust": 1.09,
#             "wind_speed": 1.04
#         },
#         {
#             "clouds": 100,
#             "dew_point": 273.92,
#             "dt": 1699506000,
#             "feels_like": 278.75,
#             "humidity": 72,
#             "pop": 0,
#             "pressure": 1010,
#             "temp": 278.75,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 217,
#             "wind_gust": 1.35,
#             "wind_speed": 1.05
#         },
#         {
#             "clouds": 100,
#             "dew_point": 273.82,
#             "dt": 1699509600,
#             "feels_like": 278.8,
#             "humidity": 71,
#             "pop": 0,
#             "pressure": 1010,
#             "temp": 278.8,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 209,
#             "wind_gust": 1.63,
#             "wind_speed": 0.91
#         },
#         {
#             "clouds": 100,
#             "dew_point": 273.85,
#             "dt": 1699513200,
#             "feels_like": 277.79,
#             "humidity": 69,
#             "pop": 0,
#             "pressure": 1010,
#             "temp": 279.29,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 224,
#             "wind_gust": 6.58,
#             "wind_speed": 2.06
#         },
#         {
#             "clouds": 100,
#             "dew_point": 275.56,
#             "dt": 1699516800,
#             "feels_like": 277.68,
#             "humidity": 72,
#             "pop": 0.78,
#             "pressure": 1011,
#             "rain": {
#                 "1h": 0.33
#             },
#             "temp": 280.36,
#             "uvi": 0.01,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 222,
#             "wind_gust": 12.54,
#             "wind_speed": 4.09
#         },
#         {
#             "clouds": 100,
#             "dew_point": 277.33,
#             "dt": 1699520400,
#             "feels_like": 278.18,
#             "humidity": 80,
#             "pop": 0.98,
#             "pressure": 1010,
#             "rain": {
#                 "1h": 0.54
#             },
#             "temp": 280.77,
#             "uvi": 0.04,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 215,
#             "wind_gust": 11.65,
#             "wind_speed": 4.1
#         },
#         {
#             "clouds": 98,
#             "dew_point": 277.42,
#             "dt": 1699524000,
#             "feels_like": 282.26,
#             "humidity": 67,
#             "pop": 0.74,
#             "pressure": 1010,
#             "temp": 283.43,
#             "uvi": 0.08,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 219,
#             "wind_gust": 15.64,
#             "wind_speed": 5.05
#         },
#         {
#             "clouds": 98,
#             "dew_point": 278.4,
#             "dt": 1699527600,
#             "feels_like": 279.36,
#             "humidity": 77,
#             "pop": 0.92,
#             "pressure": 1010,
#             "rain": {
#                 "1h": 0.27
#             },
#             "temp": 282.4,
#             "uvi": 0.1,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 226,
#             "wind_gust": 13.21,
#             "wind_speed": 6.23
#         },
#         {
#             "clouds": 98,
#             "dew_point": 279.56,
#             "dt": 1699531200,
#             "feels_like": 278.45,
#             "humidity": 88,
#             "pop": 0.99,
#             "pressure": 1009,
#             "rain": {
#                 "1h": 0.76
#             },
#             "temp": 281.57,
#             "uvi": 0.1,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 219,
#             "wind_gust": 12.78,
#             "wind_speed": 5.82
#         },
#         {
#             "clouds": 100,
#             "dew_point": 279.83,
#             "dt": 1699534800,
#             "feels_like": 279.01,
#             "humidity": 87,
#             "pop": 1,
#             "pressure": 1008,
#             "rain": {
#                 "1h": 0.32
#             },
#             "temp": 282.05,
#             "uvi": 0.08,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 213,
#             "wind_gust": 12.29,
#             "wind_speed": 5.97
#         },
#         {
#             "clouds": 100,
#             "dew_point": 279.47,
#             "dt": 1699538400,
#             "feels_like": 279.42,
#             "humidity": 83,
#             "pop": 0.72,
#             "pressure": 1008,
#             "temp": 282.36,
#             "uvi": 0.05,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 208,
#             "wind_gust": 11.84,
#             "wind_speed": 5.92
#         },
#         {
#             "clouds": 100,
#             "dew_point": 279.35,
#             "dt": 1699542000,
#             "feels_like": 279.7,
#             "humidity": 83,
#             "pop": 0.77,
#             "pressure": 1008,
#             "temp": 282.25,
#             "uvi": 0.02,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 210,
#             "wind_gust": 10.53,
#             "wind_speed": 4.78
#         }
#     ],
#     "lat": 49.0081,
#     "lon": 8.4038,
#     "timezone": "Europe/Berlin",
#     "timezone_offset": 3600
# }

# %% [markdown]
# ### Excercise: Check if it will rain in the next 12 hours

# %%
weather_data = response.json()
print(weather_data["hourly"][0]["weather"][0])
# Out:
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}

# %%
# Weather codes for the hourly forecast in the next 12 hours
for hour in range(13):
    print(f"{weather_data['hourly'][hour]['weather'][0]['id']} - {weather_data['hourly'][hour]['weather'][0]['description']}")
# Out:
# 803 - broken clouds
# 500 - light rain
# 803 - broken clouds
# 802 - scattered clouds
# 801 - few clouds
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky
# 800 - clear sky

# %%
weather_conditions : list[dict] = weather_data['hourly'][:12]
will_rain = False

for hour_data in weather_conditions:
    condition_code = hour_data['weather'][0]['id']
    if int(condition_code) < 700:
        will_rain = True
        
if will_rain:
    print("Bring an umbrella.")
# Out:
# Bring an umbrella.

# %%
# Convert dt in unix timestamp to datetime
from datetime import datetime

dt = weather_data['hourly'][1]['dt']
print(datetime.fromtimestamp(dt))

# Conclusion: Index 0 is the current weather, index 1 is the weather in the next hour and so on.
# Out:
# 2023-11-07 18:00:00

# %%
### Exercise - Sending SMS via Twilio API

from twilio.rest import Client

account_sid = "[Your Account SID]"
auth_token = "[Your Auth Token]"

if will_rain:
    client = Client(account_sid, auth_token)

    message = client.messages.create(
        body="It's going to rain today. Remember to bring an ☔️.",
        from_="[Your Twilio Phone Number]",
        to="[Your Phone Number]",
    )

    print(message.sid)
# Out:
# SM20a59ea789e2b0288811033477b7563f

# %% [markdown]
# ### Exercise - Automate Python Script with PythonAnywhere
#
# TODO

# %% [markdown]
# ### Enviroment Variables
#
# Environment variables are use to store ``sensitive information`` such as ``API keys`` and ``database credentials``. They are stored outside of the application code, and are loaded into the application at runtime. This helps to ``prevent sensitive information`` from being ``exposed`` in the application code.
#
# ```bash
# # Set Environment Variables
# export API_KEY="1234567890"
# export DB_PASSWORD="password123"
#
# # Check Environment Variables
# env | grep API_KEY
# ```
#
# ```python
# # Get Environment Variables
# import os
#
# api_key = os.environ.get("API_KEY")
# db_password = os.environ.get("DB_PASSWORD")
# ```
